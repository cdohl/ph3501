# %% [markdown]
# $$
# \newcommand{\fudm}[2]{\frac{\mathrm{D} #1}{\mathrm{D} #2}}
# \newcommand{\pad}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\ppad}[2]{\frac{\partial^2 #1}{\partial #2^2}}
# \newcommand{\ppadd}[3]{\frac{\partial^2 #1}{\partial #2 \partial #3}}
# \newcommand{\nnabla}{\nabla^2}
# \newcommand{\eps}{\epsilon}
# \newcommand{\vdetail}[1]{\vb{#1}=\begin{pmatrix}#1_1\\#1_2\\#1_3\end{pmatrix}}
# \newcommand{\vb}[1]{\mathbf{#1}}
# \newcommand{\va}[1]{\vec{#1}}
# \newcommand{\vc}[1]{\begin{pmatrix}#1_1\\#1_2\end{pmatrix}}
# \newcommand{\vd}[1]{\begin{pmatrix}#1_1\\#1_2\\#1_3\end{pmatrix}}
# \newcommand{\tb}[1]{\underline{\underline{\mathbf{#1}}}}
# \newcommand{\fud}[2]{\frac{\mathrm{d} #1}{\mathrm{d} #2}}
# \newcommand{\dd}{\mathrm{d}}
# $$

# %% [markdown]
# # Cauchy's Equation of Motion
#
# We now derive a general equation for any liquid taking into account body and surface forces.
#
# The derivation is trivial, yet we need to use a bit of vector algebra. It all starts with Newton's 2nd Law, namely the sum over all forces leads to change of momentum, i.e.:
#
# $$
# \sum \vb{F}=\fud{\vb{p}}{t}=\fud{}{t}\left( m \vb{u}\right)\tag{1}$$
#
#
# The forces acting on a fluid volume can be coarsly divided into *body forces* and *surface forces*. Body forces act at the center of the fluid particle homogeneously, while surface forces act on a specific surface, i.e. they depend on the orientation. Later below we will write down both forces but let us first have a look the right hand side of Eq. (1). In contrast to Physics 101, we can't assume a mass point but we need to integrate over the fluid particle's volume; and the momentum of the fluid particle therefore is
#
# $$\vb{p}=\int_{V(t)} \rho(\vb{x},t)\,\vb{u}\,dV\quad .\tag{2}$$
#
# The change of momentum $d\vb{p}/dt$ leads to the expression:
#
# $$\fud{}{t}\int_{V(t)} \rho(\vb{x},t)\,\vb{u}\,dV\quad .\tag{3}$$
#
# How do we differentiate this integral? The volume of the fluid particle moves in space and time, in other words the limits of the integral $V(t)$ is a function of time. Reynold's Transport Theorem allows us to differentiate the integral using only Eulerian (lab) coordinates. Reynold's transport theorem states:
#
# $$\fud{}{t}\int_{V^*(t)}F(\vb{x},t)\,dV=\int_{V^*(t)} \pad{F(\vb{x},t)}{t}\,dV+\int_{A^*(t)} F(\vb{x},t)\,\vb{b}\cdot\vb{n}\,dA\tag{4}\quad ,$$
# where the vector $\vb{b}$ in the second kernel at the R.H.S. of Eq. (4) is the velocity of of the fluid particle at its surface. You can find a detailed derivation in Kundo & Cohen, here we just take it as mathematical operation.
#
# <div class="Figure">
# <img src="files/pics/ReynoldsTransport.png" width=300>
# Figure 1 visualizes the moving liquid volume $V^*(t)$ and the change of the surface $A^*(t)$ and it's corresponding normal vector $n$.
# </div>
#
# Inserting the liquid momentum $\vb{p}$, Eq. (2) into the Reynolds transport equation Eq. (4) leads to
#
# \begin{eqnarray*}
# \fud{}{t}\int_{V(t)} \rho(\vb{x},t)\,\vb{u}\,dV&=&\int_{V(t)} \pad{(\rho(\vb{x},t)\,\vb{u}(\vb{x},t))}{t}\,dV\\
# &+&\int_{A(t)} \left(\rho(\vb{x},t)\,\vb{u}(\vb{x},t)\right)\,\left(\vb{u}\cdot\vb{n}\right)\,dA\quad,\tag{5}
# \end{eqnarray*}
#
# noting that $\vb{b}$ is the velocity of the fluid particle's surface. The second term on the R.H.S. of Eq. (5) can be converted into a volume integral using Gauss.
#
# $$\int_{A(t)} \left(\rho(\vb{x},t)\,\vb{u}(\vb{x},t)\right)\,\left(\vb{u}\cdot\vb{n}\right)\,dA=
# \int_{V(t)} \nabla \cdot \left(\rho(\vb{x},t)\,\vb{u}(\vb{x},t)\otimes\vb{u}(\vb{x},t)\right)\,dV\tag{6}
# $$
#
# The symbol $\otimes$ in the kernel of the R.H.S. of the integral is the outer product. Written in Einstein summation convention it is:
#
# $$\int_{V(t)} \pad{}{x_i}\left(\rho\,u_i\,u_j\right)\,dV\quad .\tag{7}$$
#
# Now we come to the right hand side of Newton's 2nd law, Eq. (1). Body forces act on the volume, we can therefore write them as
#
# $$\vb{F}_B=\int_{V(t)} \rho(\vb{x},t)\, \vb{g}\,dV=\int_{V(t)} \rho\,g_j\,dV\tag{8}$$
#
# while surfaces forces are directly taken from the definition of forces using the stress tensor
#
# $$\vb{F}_S=\int_{A(t)} \vb{f}(\vb{n},\vb{x},t)\, dA=\int_{A(t)} n_i \,\tau_{ij}\, dA\quad .\tag{9}$$
#
# Using again the Gauss theorem we can convert the surface integral into a volume integral
#
# $$\vb{F}_S=\int_{A(t)} n_i \,\tau_{ij}\, dA=\int_{V(t)} \pad{}{x_i}\tau_{ij}\,dV\quad.\tag{10}$$
#
#
# Now we have the L.H.S. and R.H.S of Eq. (1) written as a volume integral and can write all into the same kernel:
#
# $$\int_{V(t)}\left[\pad{}{t}\left(\rho\,u_j\right)+\pad{}{x_i}\left(\rho\,u_i\,u_j\right) -\rho\,g_j-\pad{}{x_i}\tau_{ij}\right]\,dV=0\tag{11}$$
#
# As we have allowed any liquid volume for the integral the kernel itself must be 0. Thus we can equally write Eq. (11) as
#
# $$\pad{}{t}\left(\rho\,u_j\right)+\pad{}{x_i}\left(\rho\,u_i\,u_j\right) -\rho\,g_j-\pad{}{x_i}\tau_{ij}=0\tag{12}$$
#
# Equation 12 can be simplified by factoring our $u_j$ in the second term:
#
# $$\pad{}{t}\left(\rho\,u_j\right)+\pad{}{x_i}\left(\rho\,u_i\,u_j\right)=
# \rho\pad{u_j}{t}+u_j\left[\pad{\rho}{t}+\pad{}{x_i}\left(\rho\,u_i\right)\right]+\rho\,u_i\pad{u_j}{x_i}\tag{13}$$
#
# Because of mass conservation, the second term in Eq. (13) is 0, thus Eq. (11) simplifies to:
#
# $$\rho \pad{u_j}{t} + \rho\,u_i\pad{u_j}{x_i}=\rho g_j +\pad{}{x_i}\tau_{ij}\tag{14}$$
# or
# $$\rho\fudm{u_j}{t}=\rho g_j +\pad{}{x_i}\tau_{ij}\tag{15}$$
#
# Equation (15) is named *Cauchy's Equation of Motion*. This equation describes any deformable fluid, yet it is not complete. To close the equation (that is a technical description meaning we miss something) we need to connect the stress tensor $\tau_{ij}$ with the velocity field $u_j$. This will be done in a later section.

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("styles/custom2.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
# @font-face {
# font-family: "Computer Modern";
# src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
# div.cell{
# 	width:800px;
# 	margin-left:5% !important;
# 	margin-right:auto;
# }
# div.YourWork{
# 	background-color: #FFCC66;
# }
# div.Detail{
# 	background-color: #DDEEDD;
# 	font-size: 80%;
# 	border: 1px solid black;
# 	padding: 10px;
# }
# div.Figure{
# 	border: 1px solid black;
# 	padding: 10px;
# 	text-align: center;
# 	margin: 30px;
# }
# h1 {
# font-family: 'Alegreya Sans', sans-serif;
# }
# h2 {
# font-family: 'Fenix', serif;
# }
# h3{
# font-family: 'Fenix', serif;
# margin-top:12px;
# margin-bottom: 3px;
# }
# h4{
# font-family: 'Fenix', serif;
# }
# h5 {
# font-family: 'Alegreya Sans', sans-serif;
# }
# div.text_cell_render{
# font-family: 'Alegreya Sans',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
# line-height: 135%;
# font-size: 120%;
# width:600px;
# margin-left:auto;
# margin-right:auto;
# }
# .CodeMirror{
# font-family: "Source Code Pro";
# font-size: 90%;
# }
# .rendered_html code{
# 	background-color: transparent;
# }
# /* .prompt{
# display: None;
# }*/
# .text_cell_render h1 {
# font-weight: 120;
# font-size: 30pt;
# line-height: 100%;
# color:#CD2305;
# margin-bottom: 0.5em;
# margin-top: 0.5em;
# display: block;
# }
# .text_cell_render h5 {
# font-weight: 300;
# font-size: 12pt;
# margin-bottom: 0.5em;
# margin-top: 0.5em;
# display: block;
# border-style: double;
# border-width: medium;
# border-color: black;
# background-color: #F0F0F0;
# text-align: center;
# }
# .warning{
# color: rgb( 240, 20, 20 )
# }
# </style>
# <script>
# MathJax.Hub.Config({
# TeX: {
# extensions: ["AMSmath.js"]
# },
# tex2jax: {
# inlineMath: [ ['$','$'], ["\\(","\\)"] ],
# displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
# },
# displayAlign: 'center', // Change this to 'center' to center equations.
# "HTML-CSS": {
# styles: {'.MathJax_Display': {"margin": 4}}
# }
# });
# </script>
